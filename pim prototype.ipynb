# %%
import pandas as pd
import requests
from datetime import datetime
import ibge_utilities
import importlib

# %%
importlib.reload(ibge_utilities)
dados = ibge_utilities.get_pim()
dados['1 Indústria geral'].plot()
# Out:
# <Axes: xlabel='mes_ref'>
